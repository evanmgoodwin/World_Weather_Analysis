# %%
# Import the dependencies
import pandas as pd
import matplotlib as plt
import numpy as np
import requests
from config import weather_api_key
from datetime import datetime
from citipy import citipy
import time
from scipy.stats import linregress
import gmaps
from config import g_key
import traceback

# %%
# Generate a set of 1,500 random latitudes and longitudes
lats = np.random.uniform(-90, 90, size=1500)
lngs = np.random.uniform(-180, 180, size=1500)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# %%
### Get the nearest city for the latitude and longitude combinations

# Create a list for holding the cities
cities = []

# Identify the nearest city for each combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, add it to the cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count
len(cities)
# Out:
# 621

# %%
### Perform an API call with the OpenWeatherMap

# Assign the url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the data retrieval
print("Beginning Data Retrieval        ")
print("--------------------------------")

# Loop through all the cities in the list
for i, city in enumerate(cities):
    
    # Create an endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Display the data retrieval progress
    print(f"Processing Record | {city}")
    
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve the data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_cloudiness = city_weather["clouds"]["all"]
        city_wind_speed = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # If a rain value exists, assign it a variable
        try:
            city_rain = city_weather["rain"]["3h"]
        # Otherwise, assign the variable to zero
        except KeyError:
            city_rain = 0
            
        # If a snow value exists, assign it a variable
        try:
            city_snow = city_weather["snow"]["3h"]
        # Otherwise, assign the variable to zero
        except KeyError:
            city_snow = 0
        
        # Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime("%Y-%m-%d %H:%M:%S")
        
        # Append the city information into the city data list
        city_data.append({"City": city.title(), 
                         "Lat": city_lat, 
                         "Lng": city_lng, 
                         "Max Temp": city_max_temp, 
                         "Humidity": city_humidity, 
                         "Cloudiness": city_cloudiness, 
                         "Wind Speed": city_wind_speed, 
                         "Country": city_country,
                         "Date": city_date, 
                         "Current Description": city_weather_description, 
                         "Rain inches (last 3 hrs)": city_rain,
                         "Snow inches (last 3 hrs)": city_snow})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        continue

# Indicate that the data retrieval is complete
print("--------------------------------")
print("Data Retrieval Complete         ")
print("--------------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record | hithadhoo
# Processing Record | codrington
# Processing Record | coquimbo
# Processing Record | mataura
# Processing Record | busselton
# City not found. Skipping...
# Processing Record | bilibino
# Processing Record | berlevag
# Processing Record | rikitea
# Processing Record | castro
# Processing Record | mahajanga
# Processing Record | barreiro
# Processing Record | albuquerque
# Processing Record | hambantota
# Processing Record | myaundzha
# Processing Record | ekuvukeni
# Processing Record | emporia
# Processing Record | kapaa
# Processing Record | carauari
# Processing Record | bethel
# Processing Record | omsukchan
# Processing Record | mbigou
# Processing Record | idlib
# Processing Record | bathsheba
# Processing Record | cap malheureux
# Processing Record | isangel
# City not found. Skipping...
# Processing Record | belushya guba
# City not found. Skipping...
# Processing Record | nicoya
# Processing Record | mosetse
# Processing Record | taolanaro
# City not found. Skipping...
# Processing Record | jamestown
# Processing Record | cape town
# Processing Record | ancud
# Processing Record | matagami
# Processing Record | la ronge
# Processing Record | hilo
# Processing Record | ushuaia
# Processing Record | lumberton
# Processing Record | vezirkopru
# Processing Record | bredasdorp
# Processing Record | severo-kurilsk
# Processing Record | karad
# Processing Record | dingle
# Processing Record | saint-philippe
# Processing Record | puerto ayora
# Processing Record | ribeira grande
# Processing Record | khatanga
# Processing Record | padang
# Processing Record | hermanus
# Processing Record | simao
# Processing Record | socorro
# Processing Record | paamiut
# Processing Record | faanui
# Processing Record | krasnoselkup
# Processing Record | tasiilaq
# Processing Record | mancora
# Processing Record | bluff
# Processing Record | karakendzha
# City not found. Skipping...
# Processing Record | fiumicino
# Processing Record | avarua
# Processing Record | chokurdakh
# Processing Record | grafing
# Processing Record | quatre cocos
# Processing Record | punta arenas
# Processing Record | vaini
# Processing Record | grand gaube
# Processing Record | atuona
# Processing Record | xichang
# Processing Record | ewa beach
# Processing Record | attawapiskat
# City not found. Skipping...
# Processing Record | albany
# Processing Record | provideniya
# Processing Record | korla
# Processing Record | port elizabeth
# Processing Record | asau
# Processing Record | kazalinsk
# City not found. Skipping...
# Processing Record | revda
# Processing Record | coxim
# City not found. Skipping...
# Processing Record | lavrentiya
# City not found. Skipping...
# Processing Record | new norfolk
# Processing Record | boralday
# Processing Record | tierra blanca
# Processing Record | luderitz
# Processing Record | mahebourg
# Processing Record | areosa
# Processing Record | college
# Processing Record | alyangula
# Processing Record | bam
# Processing Record | khor
# Processing Record | hobart
# Processing Record | nome
# Processing Record | talara
# Processing Record | lasa
# Processing Record | kenai
# Processing Record | guerrero negro
# Processing Record | sao filipe
# Processing Record | whangarei
# Processing Record | yar-sale
# Processing Record | holme
# Processing Record | butaritari
# Processing Record | qaanaaq
# Processing Record | murliganj
# Processing Record | axim
# Processing Record | saryshagan
# City not found. Skipping...
# Processing Record | lower burrell
# Processing Record | barao de melgaco
# Processing Record | nizhneyansk
# City not found. Skipping...
# Processing Record | cabo san lucas
# Processing Record | glubokiy
# Processing Record | tabuk
# Processing Record | zhanatas
# City not found. Skipping...
# Processing Record | tsihombe
# City not found. Skipping...
# Processing Record | auki
# Processing Record | mar del plata
# Processing Record | nikolskoye
# Processing Record | carutapera
# Processing Record | kamenskoye
# City not found. Skipping...
# Processing Record | iqaluit
# Processing Record | gunnedah
# Processing Record | dumingag
# Processing Record | rezekne
# Processing Record | shakawe
# Processing Record | illoqqortoormiut
# City not found. Skipping...
# Processing Record | miraflores
# Processing Record | komsomolskiy
# Processing Record | alofi
# Processing Record | arraial do cabo
# Processing Record | kungurtug
# Processing Record | east london
# Processing Record | barrow
# Processing Record | linhai
# Processing Record | anito
# Processing Record | lebu
# Processing Record | hay river
# Processing Record | iquitos
# Processing Record | chuy
# Processing Record | sao jose da coroa grande
# Processing Record | gobabis
# Processing Record | saint-augustin
# Processing Record | kalisz
# Processing Record | strezhevoy
# Processing Record | dustlik
# Processing Record | talcahuano
# Processing Record | comodoro rivadavia
# City not found. Skipping...
# Processing Record | veere
# Processing Record | victoria
# Processing Record | pangnirtung
# Processing Record | biak
# Processing Record | kiama
# Processing Record | college place
# Processing Record | sorong
# Processing Record | lompoc
# Processing Record | jalu
# Processing Record | llanes
# Processing Record | evensk
# Processing Record | aksu
# Processing Record | mayo
# Processing Record | bonthe
# Processing Record | yarmouth
# Processing Record | cidreira
# Processing Record | punta alta
# Processing Record | nauchnyy gorodok
# Processing Record | lieksa
# Processing Record | carnarvon
# Processing Record | tutla
# City not found. Skipping...
# Processing Record | saskylakh
# Processing Record | makakilo city
# Processing Record | jertih
# Processing Record | margate
# Processing Record | airai
# Processing Record | fare
# Processing Record | tiksi
# Processing Record | chemax
# Processing Record | tumannyy
# City not found. Skipping...
# Processing Record | nanortalik
# Processing Record | wamba
# Processing Record | ust-nera
# Processing Record | kavieng
# Processing Record | aklavik
# Processing Record | mildura
# Processing Record | minas
# Processing Record | tabou
# Processing Record | pisco
# Processing Record | lebedinyy
# Processing Record | komatipoort
# Processing Record | ponta do sol
# Processing Record | vanderhoof
# Processing Record | correntina
# Processing Record | mangan
# Processing Record | port alfred
# Processing Record | acapulco
# Processing Record | mys shmidta
# City not found. Skipping...
# Processing Record | oktyabrskoye
# Processing Record | leo
# Processing Record | pangkalanbuun
# Processing Record | hollola
# Processing Record | vila do maio
# Processing Record | clyde river
# Processing Record | hofn
# City not found. Skipping...
# Processing Record | batamshinskiy
# Processing Record | kirakira
# Processing Record | san andres
# Processing Record | hvide sande
# Processing Record | luceville
# City not found. Skipping...
# Processing Record | sunrise manor
# Processing Record | san jose del guaviare
# Processing Record | caravelas
# Processing Record | vao
# Processing Record | nouadhibou
# Processing Record | grand river south east
# City not found. Skipping...
# Processing Record | puerto del rosario
# Processing Record | kangaatsiaq
# Processing Record | yellowknife
# Processing Record | srivardhan
# Processing Record | ossora
# Processing Record | barawe
# City not found. Skipping...
# Processing Record | swift current
# Processing Record | turkmenabat
# Processing Record | filadelfia
# Processing Record | ostrovnoy
# Processing Record | paradwip
# City not found. Skipping...
# Processing Record | bafoulabe
# Processing Record | souillac
# Processing Record | dunedin
# Processing Record | verkhoyansk
# City not found. Skipping...
# Processing Record | fortuna
# Processing Record | talnakh
# Processing Record | tuatapere
# Processing Record | esperance
# Processing Record | kruisfontein
# Processing Record | khandyga
# Processing Record | templemore
# Processing Record | hamilton
# Processing Record | beira
# Processing Record | porto novo
# Processing Record | tilichiki
# Processing Record | vestmannaeyjar
# Processing Record | chalus
# Processing Record | marawi
# Processing Record | las vegas
# Processing Record | moba
# Processing Record | zhangye
# Processing Record | roald
# Processing Record | henties bay
# Processing Record | lethem
# Processing Record | igarka
# Processing Record | laguna
# Processing Record | saldanha
# Processing Record | honningsvag
# Processing Record | georgetown
# Processing Record | atasu
# Processing Record | santa rosalia
# Processing Record | lepley
# Processing Record | broome
# Processing Record | jardanhaza
# Processing Record | santa catalina
# Processing Record | bonavista
# Processing Record | galanta
# Processing Record | gravdal
# Processing Record | sao felix do xingu
# Processing Record | thompson
# Processing Record | longyearbyen
# Processing Record | harrison
# Processing Record | erzin
# Processing Record | churapcha
# Processing Record | kaihua
# Processing Record | baruun-urt
# Processing Record | necochea
# Processing Record | banda aceh
# Processing Record | pevek
# Processing Record | ngaoundere
# Processing Record | erdemli
# Processing Record | wewak
# Processing Record | palmer
# Processing Record | opuwo
# Processing Record | tokur
# Processing Record | laiagam
# City not found. Skipping...
# Processing Record | sindand
# City not found. Skipping...
# Processing Record | skorodnoye
# Processing Record | raga
# Processing Record | galveston
# Processing Record | talakan
# Processing Record | kirkwall
# Processing Record | dikson
# Processing Record | beloha
# Processing Record | krivosheino
# Processing Record | crotone
# Processing Record | beringovskiy
# Processing Record | calbuco
# Processing Record | samalaeulu
# City not found. Skipping...
# Processing Record | kahului
# Processing Record | pacific grove
# Processing Record | campoverde
# Processing Record | leeds
# Processing Record | scarborough
# Processing Record | husavik
# Processing Record | rio grande
# Processing Record | touros
# Processing Record | upernavik
# Processing Record | takestan
# Processing Record | fort nelson
# Processing Record | acajutla
# Processing Record | soria
# Processing Record | mount gambier
# Processing Record | bandarbeyla
# Processing Record | saint george
# Processing Record | acarau
# Processing Record | pedernales
# Processing Record | abong mbang
# Processing Record | rawlins
# Processing Record | san quintin
# Processing Record | puno
# Processing Record | constitucion
# Processing Record | salalah
# Processing Record | mackay
# Processing Record | svetlaya
# Processing Record | waren
# Processing Record | udachnyy
# Processing Record | pimentel
# Processing Record | cap-aux-meules
# Processing Record | ryotsu
# Processing Record | buqayq
# City not found. Skipping...
# Processing Record | grand forks
# Processing Record | griffith
# Processing Record | ayan
# Processing Record | klaksvik
# Processing Record | zhigansk
# Processing Record | villa carlos paz
# Processing Record | horsham
# Processing Record | linapacan
# City not found. Skipping...
# Processing Record | harper
# Processing Record | jizan
# Processing Record | vestmanna
# Processing Record | kodiak
# Processing Record | safita
# Processing Record | sakhnovshchyna
# Processing Record | toamasina
# Processing Record | kiunga
# Processing Record | paciran
# Processing Record | bengkulu
# Processing Record | anthia
# City not found. Skipping...
# Processing Record | sambava
# Processing Record | inirida
# Processing Record | krasnyy chikoy
# Processing Record | westport
# Processing Record | takoradi
# Processing Record | dhidhdhoo
# Processing Record | luganville
# Processing Record | rundu
# Processing Record | shache
# Processing Record | cherskiy
# Processing Record | belyy yar
# Processing Record | lewiston
# Processing Record | nelson bay
# Processing Record | kisiwani
# Processing Record | mexico
# Processing Record | ixtapa
# Processing Record | mandalgovi
# Processing Record | srednekolymsk
# Processing Record | dakar
# Processing Record | dovbysh
# Processing Record | burica
# City not found. Skipping...
# Processing Record | lesnoye
# Processing Record | banjar
# Processing Record | krasnoyarka
# Processing Record | mayumba
# Processing Record | rocha
# Processing Record | mingshui
# Processing Record | luangwa
# Processing Record | samusu
# City not found. Skipping...
# Processing Record | road town
# Processing Record | casino
# Processing Record | turukhansk
# Processing Record | avera
# Processing Record | urumqi
# Processing Record | sinnamary
# Processing Record | xacmaz
# Processing Record | amga
# Processing Record | dolbeau
# City not found. Skipping...
# Processing Record | sinalunga
# Processing Record | lagoa
# Processing Record | tuktoyaktuk
# Processing Record | agboville
# Processing Record | vardo
# Processing Record | vorukh
# Processing Record | mahibadhoo
# Processing Record | geraldton
# Processing Record | ust-kut
# Processing Record | puerto baquerizo moreno
# Processing Record | vangaindrano
# Processing Record | xuanhua
# Processing Record | guelengdeng
# City not found. Skipping...
# Processing Record | diego de almagro
# Processing Record | tual
# Processing Record | sentyabrskiy
# City not found. Skipping...
# Processing Record | linkoping
# Processing Record | hasaki
# Processing Record | kendari
# Processing Record | marienburg
# Processing Record | saleaula
# City not found. Skipping...
# Processing Record | sur
# Processing Record | garissa
# Processing Record | chapais
# Processing Record | belaya gora
# Processing Record | kalavad
# Processing Record | uchiza
# Processing Record | ahipara
# Processing Record | barentsburg
# City not found. Skipping...
# Processing Record | natal
# Processing Record | lorengau
# Processing Record | yambio
# Processing Record | abu dhabi
# Processing Record | solginskiy
# Processing Record | sangar
# Processing Record | sao miguel do araguaia
# Processing Record | lazaro cardenas
# Processing Record | florenville
# Processing Record | norman wells
# Processing Record | dalton
# Processing Record | lulea
# Processing Record | pajan
# Processing Record | torbay
# Processing Record | najran
# Processing Record | batemans bay
# Processing Record | macaboboni
# City not found. Skipping...
# Processing Record | richards bay
# Processing Record | khandela
# Processing Record | kaitangata
# Processing Record | coihaique
# Processing Record | kasane
# Processing Record | sorland
# Processing Record | marcona
# City not found. Skipping...
# Processing Record | chom bung
# City not found. Skipping...
# Processing Record | grand-santi
# Processing Record | oranjemund
# Processing Record | matara
# Processing Record | sosnovo-ozerskoye
# Processing Record | yakymivka
# Processing Record | naze
# Processing Record | sumenep
# Processing Record | katangli
# Processing Record | arlit
# Processing Record | banff
# Processing Record | sao joao da barra
# Processing Record | gambela
# Processing Record | haines junction
# Processing Record | nynashamn
# Processing Record | nantucket
# Processing Record | kupang
# Processing Record | pontianak
# Processing Record | teya
# Processing Record | ngunguru
# Processing Record | tiznit
# Processing Record | santa vitoria do palmar
# Processing Record | botro
# Processing Record | tahta
# Processing Record | eskasem
# City not found. Skipping...
# Processing Record | kalaswala
# Processing Record | yumen
# Processing Record | gondar
# Processing Record | altay
# Processing Record | meulaboh
# Processing Record | port lincoln
# Processing Record | mehamn
# Processing Record | okhotsk
# Processing Record | novaya igirma
# Processing Record | gushikawa
# Processing Record | paita
# Processing Record | szomod
# Processing Record | dalinghe
# City not found. Skipping...
# Processing Record | panaba
# Processing Record | ilulissat
# Processing Record | sawakin
# Processing Record | lashio
# Processing Record | yaan
# Processing Record | kinwat
# Processing Record | shagonar
# Processing Record | san patricio
# Processing Record | garoua boulai
# Processing Record | ekhabi
# Processing Record | borova
# Processing Record | witbank
# Processing Record | lovozero
# Processing Record | port keats
# Processing Record | akyab
# Processing Record | narsaq
# Processing Record | logansport
# Processing Record | walvis bay
# Processing Record | chimbote
# Processing Record | zachagansk
# City not found. Skipping...
# Processing Record | menasha
# Processing Record | kudahuvadhoo
# Processing Record | port augusta
# Processing Record | uyemskiy
# Processing Record | lobatse
# Processing Record | balsas
# Processing Record | portland
# Processing Record | cururupu
# Processing Record | ballina
# Processing Record | kutum
# Processing Record | morant bay
# Processing Record | nadym
# Processing Record | viedma
# Processing Record | samaipata
# Processing Record | grand bank
# Processing Record | blagoyevo
# Processing Record | aripuana
# Processing Record | zheleznodorozhnyy
# Processing Record | namibe
# Processing Record | coos bay
# Processing Record | the valley
# Processing Record | meyungs
# City not found. Skipping...
# Processing Record | khorixas
# Processing Record | bahia blanca
# Processing Record | vanimo
# Processing Record | jahrom
# City not found. Skipping...
# Processing Record | kandrian
# Processing Record | solovetskiy
# City not found. Skipping...
# Processing Record | moranbah
# Processing Record | london
# Processing Record | ponta delgada
# Processing Record | toktogul
# Processing Record | bereda
# Processing Record | ulladulla
# Processing Record | mirnyy
# Processing Record | katsuura
# Processing Record | dujuma
# City not found. Skipping...
# Processing Record | caucaia
# Processing Record | gelibolu
# Processing Record | havelock
# Processing Record | campbeltown
# Processing Record | karratha
# Processing Record | bambous virieux
# Processing Record | havoysund
# Processing Record | teguldet
# Processing Record | vendychany
# Processing Record | puerto escondido
# Processing Record | mareeba
# Processing Record | omboue
# Processing Record | trelew
# Processing Record | gao
# Processing Record | byron bay
# Processing Record | camopi
# Processing Record | puerto leguizamo
# Processing Record | san policarpo
# Processing Record | gorontalo
# Processing Record | agadir
# Processing Record | lata
# Processing Record | itarema
# Processing Record | goure
# Processing Record | coruripe
# Processing Record | ginir
# Processing Record | umm lajj
# Processing Record | jalingo
# Processing Record | azimur
# City not found. Skipping...
# Processing Record | sabaudia
# Processing Record | vaitupu
# City not found. Skipping...
# Processing Record | perevolotskiy
# Processing Record | yulara
# Processing Record | doha
# Processing Record | ambulu
# Processing Record | karamea
# City not found. Skipping...
# Processing Record | manacapuru
# Processing Record | reconquista
# Processing Record | pafos
# Processing Record | prince rupert
# Processing Record | hami
# Processing Record | shimoda
# Processing Record | san juan del sur
# Processing Record | yagodnoye
# Processing Record | kothapet
# Processing Record | halalo
# City not found. Skipping...
# Processing Record | khonuu
# City not found. Skipping...
# Processing Record | zyryanka
# Processing Record | viramgam
# Processing Record | badvel
# Processing Record | port hardy
# Processing Record | markala
# City not found. Skipping...
# Processing Record | japura
# Processing Record | taoudenni
# Processing Record | poum
# Processing Record | riberalta
# City not found. Skipping...
# Processing Record | sitka
# Processing Record | waddan
# Processing Record | tevriz
# Processing Record | obidos
# Processing Record | rantauprapat
# Processing Record | tamandare
# Processing Record | huarmey
# Processing Record | mount isa
# Processing Record | lakeland highlands
# Processing Record | tautira
# Processing Record | tromso
# Processing Record | voh
# Processing Record | lewistown
# Processing Record | sakakah
# Processing Record | baykit
# Processing Record | kraskino
# Processing Record | tevaitoa
# Processing Record | charters towers
# Processing Record | launceston
# Processing Record | stornoway
# Processing Record | kudchi
# City not found. Skipping...
# Processing Record | bagdarin
# Processing Record | kumluca
# Processing Record | asyut
# Processing Record | saint andrews
# Processing Record | mrirt
# City not found. Skipping...
# Processing Record | pathein
# Processing Record | cuaspud
# Processing Record | nanuque
# Processing Record | of
# City not found. Skipping...
# Processing Record | iberia
# Processing Record | amderma
# City not found. Skipping...
# Processing Record | namatanai
# Processing Record | guanica
# Processing Record | aksarka
# Processing Record | viseu
# Processing Record | verkhneyarkeyevo
# Processing Record | rio gallegos
# Processing Record | saint stephen
# Processing Record | antequera
# --------------------------------
# Data Retrieval Complete
# --------------------------------

# %%
# Check to see how many cities were found
len(city_data)
# Out:
# 562

# %%
# Convert the array of dictionaries to a dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                  City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           Hithadhoo  -0.60   73.08     84.81        72          36
# 1          Codrington -38.27  141.97     55.90        76          90
# 2            Coquimbo -29.95  -71.34     62.60        77           0
# 3             Mataura -46.19  168.86     50.00        91         100
# 4            Bilibino  68.05  166.44     -2.24        85          12
# ..                ...    ...     ...       ...       ...         ...
# 557             Viseu  40.66   -7.91     61.00         1           4
# 558  Verkhneyarkeyevo  55.45   54.31     38.61        83          42
# 559      Rio Gallegos -51.62  -69.22     60.80        38           0
# 560     Saint Stephen  50.33   -4.90     52.00        93         100
# 561         Antequera  37.02   -4.56     62.60        77          20
#
#      Wind Speed Country                 Date Current Description  \
# 0          7.27      MV  2020-04-17 19:28:23    scattered clouds
# 1         12.77      AU  2020-04-17 19:26:43          light rain
# 2         16.11      CL  2020-04-17 19:28:24           clear sky
# 3          7.00      NZ  2020-04-17 19:28:25          light rain
# 4          4.76      RU  2020-04-17 19:28:27          few clouds
# ..          ...     ...                  ...                 ...
# 557        3.00      PT  2020-04-17 19:32:01           clear sky
# 558       11.61      RU  2020-04-17 19:34:50    scattered clouds
# 559       19.46      AR  2020-04-17 19:34:51           clear sky
# 560       23.04      GB  2020-04-17 19:34:52          light rain
# 561        8.05      ES  2020-04-17 19:34:53          few clouds
#
#      Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0                        0.00                       0.0
# 1                        0.16                       0.0
# 2                        0.00                       0.0
# 3                        0.12                       0.0
# 4                        0.00                       0.0
# ..                        ...                       ...
# 557                      0.00                       0.0
# 558                      0.00                       0.0
# 559                      0.00                       0.0
# 560                      0.45                       0.0
# 561                      0.00                       0.0
#
# [562 rows x 12 columns]

# %%
# Rearrange column order
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Rain inches (last 3 hrs)", "Snow inches (last 3 hrs)"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                  City Country                 Date    Lat     Lng  Max Temp  \
# 0           Hithadhoo      MV  2020-04-17 19:28:23  -0.60   73.08     84.81
# 1          Codrington      AU  2020-04-17 19:26:43 -38.27  141.97     55.90
# 2            Coquimbo      CL  2020-04-17 19:28:24 -29.95  -71.34     62.60
# 3             Mataura      NZ  2020-04-17 19:28:25 -46.19  168.86     50.00
# 4            Bilibino      RU  2020-04-17 19:28:27  68.05  166.44     -2.24
# ..                ...     ...                  ...    ...     ...       ...
# 557             Viseu      PT  2020-04-17 19:32:01  40.66   -7.91     61.00
# 558  Verkhneyarkeyevo      RU  2020-04-17 19:34:50  55.45   54.31     38.61
# 559      Rio Gallegos      AR  2020-04-17 19:34:51 -51.62  -69.22     60.80
# 560     Saint Stephen      GB  2020-04-17 19:34:52  50.33   -4.90     52.00
# 561         Antequera      ES  2020-04-17 19:34:53  37.02   -4.56     62.60
#
#      Humidity  Cloudiness  Wind Speed Current Description  \
# 0          72          36        7.27    scattered clouds
# 1          76          90       12.77          light rain
# 2          77           0       16.11           clear sky
# 3          91         100        7.00          light rain
# 4          85          12        4.76          few clouds
# ..        ...         ...         ...                 ...
# 557         1           4        3.00           clear sky
# 558        83          42       11.61    scattered clouds
# 559        38           0       19.46           clear sky
# 560        93         100       23.04          light rain
# 561        77          20        8.05          few clouds
#
#      Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0                        0.00                       0.0
# 1                        0.16                       0.0
# 2                        0.00                       0.0
# 3                        0.12                       0.0
# 4                        0.00                       0.0
# ..                        ...                       ...
# 557                      0.00                       0.0
# 558                      0.00                       0.0
# 559                      0.00                       0.0
# 560                      0.45                       0.0
# 561                      0.00                       0.0
#
# [562 rows x 12 columns]

# %%
# Format the rain and snow columns
city_data_df["Rain inches (last 3 hrs)"] = city_data_df["Rain inches (last 3 hrs)"].map("{:.3f}".format)

city_data_df["Snow inches (last 3 hrs)"] = city_data_df["Snow inches (last 3 hrs)"].map("{:.0f}".format)

city_data_df
# Out:
#                  City Country                 Date    Lat     Lng  Max Temp  \
# 0           Hithadhoo      MV  2020-04-17 19:28:23  -0.60   73.08     84.81
# 1          Codrington      AU  2020-04-17 19:26:43 -38.27  141.97     55.90
# 2            Coquimbo      CL  2020-04-17 19:28:24 -29.95  -71.34     62.60
# 3             Mataura      NZ  2020-04-17 19:28:25 -46.19  168.86     50.00
# 4            Bilibino      RU  2020-04-17 19:28:27  68.05  166.44     -2.24
# ..                ...     ...                  ...    ...     ...       ...
# 557             Viseu      PT  2020-04-17 19:32:01  40.66   -7.91     61.00
# 558  Verkhneyarkeyevo      RU  2020-04-17 19:34:50  55.45   54.31     38.61
# 559      Rio Gallegos      AR  2020-04-17 19:34:51 -51.62  -69.22     60.80
# 560     Saint Stephen      GB  2020-04-17 19:34:52  50.33   -4.90     52.00
# 561         Antequera      ES  2020-04-17 19:34:53  37.02   -4.56     62.60
#
#      Humidity  Cloudiness  Wind Speed Current Description  \
# 0          72          36        7.27    scattered clouds
# 1          76          90       12.77          light rain
# 2          77           0       16.11           clear sky
# 3          91         100        7.00          light rain
# 4          85          12        4.76          few clouds
# ..        ...         ...         ...                 ...
# 557         1           4        3.00           clear sky
# 558        83          42       11.61    scattered clouds
# 559        38           0       19.46           clear sky
# 560        93         100       23.04          light rain
# 561        77          20        8.05          few clouds
#
#     Rain inches (last 3 hrs) Snow inches (last 3 hrs)
# 0                      0.000                        0
# 1                      0.160                        0
# 2                      0.000                        0
# 3                      0.120                        0
# 4                      0.000                        0
# ..                       ...                      ...
# 557                    0.000                        0
# 558                    0.000                        0
# 559                    0.000                        0
# 560                    0.450                        0
# 561                    0.000                        0
#
# [562 rows x 12 columns]

# %%
### Save the dataframe as a csv file

# Create the output file
output_data_file = "weather_data/WeatherPy_Challenge.csv"

# Export the city_data to the csv
city_data_df.to_csv(output_data_file, index_label="City ID")

# %%
### How many cities have rainfall and snowfall? ###

# Find the cities with recorded rainfall
cities_with_rain = city_data_df.loc[(city_data_df["Rain inches (last 3 hrs)"] > "0.000")]
print(f"There are {len(cities_with_rain)} cities with recorded rainfall.")

# Find the cities with recorded snowfall
cities_with_snow = city_data_df.loc[(city_data_df["Snow inches (last 3 hrs)"] > "0")]
print(f"There are {len(cities_with_snow)} cities with recorded snowfall.")
# Out:
# There are 86 cities with recorded rainfall.
# There are 4 cities with recorded snowfall.
